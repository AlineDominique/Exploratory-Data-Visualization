# %% [markdown]
# <h3>1. Instrução</h3>
# <ol>
# <li>Vamos configurar o ambiente importando as bibliotecas necessárias e executando a mágica necessária do Jupyter para que os gráficos sejam exibidos em linha.</li>
# <ul>
# <li>Importe pandas e matplotlib para o ambiente;</li>
# <li>Execute o Jupyter <i>%matplotlib inline</i> para que os gráficos sejam exibidos inline.</li>
# </ul>
# <li>Leia o dataset e comece a explorar.</li>
# <ul>
# <li>Leia o arquivo <b>recent-grads.csv</b> com o pandas e atribua o resultado a variavel <b>recent-grads</b>.</li>
# <li>Use o <i>DataFrame.iloc[]</i> para retornar a primeira linha formatada como tabela.</li>
# <li>Use o <i>DataFrame.head()</i> e <i>DataFrame.tail()</i> para se familizar com a estruturada dos dados.</li>
# <li>Use o <i>DataFrame.describe()</i> para gerar um sumário de estatisticas com todas colunas com valores númericos.</li>
# </ul>
# <li>Exclua as linhas sem valores. O Matplotlib espera que as colunas de valores que passamos tenham comprimentos correspondentes e os valores ausentes farão com que o matplotlib gere erros.
# </li>
# <ul>
# <li>Procure o número de linhas em <b>recent_grads</b> e atribua o valor a <b>raw_data_count</b>.</li>
# <li>Use <i>DataFrame.dropna()</i> para descartar linhas que contêm valores ausentes e atribua o DataFrame resultante novamente a <b>recent_grads</b>.</li>
# <li>Procure o número de linhas em <b>recent_grads</b> agora e atribua o valor a <b>clean_data_count</b>. Se você comparar <b>clean_data_count</b> e <b>raw_data_count</b>, notará que apenas uma linha continha valores ausentes e foi descartada.</li>
# </ul>
# </ol>

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[:0]
# Out:
# Empty DataFrame
# Columns: [Rank, Major_code, Major, Total, Men, Women, Major_category, ShareWomen, Sample_size, Employed, Full_time, Part_time, Full_time_year_round, Unemployed, Unemployment_rate, Median, P25th, P75th, College_jobs, Non_college_jobs, Low_wage_jobs]
# Index: []
#
# [0 rows x 21 columns]

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
print(raw_data_count)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 172

# %% [markdown]
# <h3>2. Instruções</h3>
# <ol>
# <li>Gere gráficos de dispersão em celulas separadas no jupyter notebook e explore as seguintes relações:</li>
# <ul>
# <li><b>Sample_size</b> e <b>Median</b></li>
# <li><b>Sample_size</b> e <b>Unemployment_rate</b></li>
# <li><b>Full_time</b> e <b>Median</b></li>
# <li><b>ShareWomen</b> e <b>Unemployment_rate</b></li>
# <li><b>Men</b> e <b>Median</b></li>
# <li><b>Women</b> e <b>Median</b></li>
# </ul>
# <li>Use os gráfico para explicar as seguintes questões:</li>
# <ul>
# <li>Os estudantes mais de graduções mais populares tem sálarios mais altos?</li>
# <li>Os alunos que se formaram em matérias que eram majoritariamente femininas ganham mais dinheiro?</li>
# <li>Há qualquer relação entre o número de trabalhadores full-time e o salario médio?</li>
# </ul>
# </ol>

# %%
#Sample_size e Median
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample Size vs. Median', figsize=(10,10))

# %%
#Sample_size e Unemployment_rate
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', 
                        title='Sample Size vs. Unemployment Rate',
                        figsize=(5,10))

# %%
#Full_time and Median
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter', 
                        title='Full Time vs. Median', figsize=(10,10))

# %%
#ShareWomen e Unemployment_rate
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', 
                        title='ShareWomen vs. Unemployment Rate', figsize=(10,10))

# %%
#Men e Median
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter', 
                        title='Men vs. Median', figsize=(10,10))

# %%
#Women e Median
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter', 
                        title='Women vs. Median', figsize=(10,10))

# %% [markdown]
# <p>Os estudantes mais de graduções mais populares tem sálarios mais altos?
# R: Há qualquer relação de que os cursos mais populares possui maiores salarios. No mostra no grafico ax1.
# </p>
# <p>Os alunos que se formaram em matérias que eram majoritariamente femininas ganham mais dinheiro?
# R: Como mostrado no gráfico de dispersão abaixo matérias com mais mulheres possui sálario médio entre 20.000 a 40.000 de dolares, o que não são valores tão altos.
# </p>
# <p>Há qualquer relação entre o número de trabalhadores full-time e o salario médio?
# R: A maior parte dos trabalhadores de período integral tem a média sálario entre 20.000 a 40.000 de dolares. São raras os trabalhadores que ultrapassam os 100.000 de dolares.
# </p>

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter', 
                        title='ShareWomen vs. Median', figsize=(10,10))

# %% [markdown]
# <h3>3. Intruções</h3>
# <ol>
# <li>Gere o um histograma em cada célula para separadamente e explore a distruibição das sequintes colunas:</li>
# <ul>
# <li>Sample_size</li>
# <li>Median</li>
# <li>Employed</li>
# <li>Full_time</li>
# <li>ShareWomen</li>
# <li>Unemployment_rate</li>
# <li>Men</li>
# <li>Women</li>
# </ul>
# <li>Nós encorajamos você testar diferentes tamanhos de bin e ranges para construir o gráficos.</li>
# <li>Use os gráficos que explorados para responder as sequintes questões:</li>
# <ul>
# <li>Qual a porcentagem das graduações que maioria é masculina? E maioria é feminina?</li>
# <li>Qual a média sálario mais comum na lista de sálarios?</li>
# </ul>
# </ol>

# %%
recent_grads['Sample_size'].hist(bins=20, range=(0,5000))

# %%
#median_salary = recent_grads['Median'].value_counts()
#print(median_salary)
recent_grads['Median'].value_counts().hist(bins=10,range=(0,20))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Full_time'].hist(bins=15, range=(0,5000))

# %%
recent_grads['ShareWomen'].hist(bins=10, range=(0,1000))

# %%
recent_grads['Unemployment_rate'].hist(bins=5, range=(0,500))

# %%
recent_grads['Men'].hist(bins=10, range=(0,500))

# %%
recent_grads['Women'].hist(bins=10, range=(0,500))

# %% [markdown]
# <p>Qual a média sálario mais comum na lista de sálarios?<br>R:O salário mais comum é na faixa 35.000 dolares.</p>

# %% [markdown]
# <h3>4. Instruções</h3>
# <ol>
# <li>Importe <b>scatter_matrix</b> do módulo <b>andas.plotting</b>.</li>
# <li>Crie um gráfico de dispersão 2 por 2 usando as colunas <b>Sample_size</b> e <b>Median</b>.</li>
# <li>Crie um gáfico de dispersão 3 por 3 usando as colunas <b>Sample_size</b>, <b>Median</b> e <b>Unemployment_rate</b>.</li>
# <li>Explore as perguntas das últimas etapas usando esses gráficos de matriz de dispersão. Pode ser necessário criar mais gráficos de matriz de dispersão.</li>
# </ol>

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Women', 'Men']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c4160d240>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Women', 'Men','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c403ea048>,
# ...
#       dtype=object)

# %% [markdown]
# <h3>5. Instruções</h3>
# <ol>
# <li>Use gráficos de barras para comparar as porcentagens de mulheres (<b>ShareWomen</b>) das dez primeiras linhas e das últimas dez linhas do quadro de dados <b>recent_grads</b>.</li>
# <li>Use gráficos de barras para comparar a taxa de desemprego (<b>Unemployment_rate</b>) das dez primeiras linhas e das últimas dez linhas do quadro de dados <b>recent_grads</b>.</li>
# </ol>

# %%
recent_grads[:11]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[162:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads[162:]['Unemployment_rate'].plot(kind='bar')

# %% [markdown]
# <h3>Outras Visualizações dos Dados</h3>
# <ol>
# <li>Use um gráfico de barras agrupadas para comparar o número de homens com o número de mulheres em cada categoria de maiores.</li>
# <li>Use um gráfico de box plot para explorar as distribuições de salários médios e taxa de desemprego.
# </li>
# </ol>

# %%
recent_grads[:10].plot.bar(x='Major', y='Women')

# %%
recent_grads.plot.bar(x='Men',y='Major')
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-50-0e98bac74904> in <module>()
# ----> 1 recent_grads.plot.bar(x='Men', y='Major')
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    2714         axes : matplotlib.AxesSubplot or np.array of them
#    2715         """
# -> 2716         return self(kind='bar', x=x, y=y, **kwds)
#    2717
#    2718     def barh(self, x=None, y=None, **kwds):
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# ...
